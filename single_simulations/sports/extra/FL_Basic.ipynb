# %%
import pandas as pd
import numpy as np

# %%
reviews = pd.read_csv("data/reviews_sports.csv")
ratings = pd.read_csv("data/Sports_and_Outdoors.csv")
# Out:
# /var/folders/l2/_mks1sd56yjdxq9514qt1fnh0000gn/T/ipykernel_18543/4062999.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   reviews = pd.read_csv("data/reviews_sports.csv")

# %%
ratings.columns = ['asin','reviewerID','ratings','unixReviewTime']

# %%
reviews
# Out:
#          Unnamed: 0  overall  verified   reviewTime      reviewerID  \
# 0                 0      5.0      True   06 3, 2015  A180LQZBUWVOLF
# 1                 1      1.0      True   04 1, 2015   ATMFGKU5SVEYY
# 2                 2      5.0      True  01 13, 2015  A1QE70QBJ8U6ZG
# 3                 3      5.0      True  12 23, 2014  A22CP6Z73MZTYU
# 4                 4      4.0      True  12 15, 2014  A22L28G8NRNLLN
# ...             ...      ...       ...          ...             ...
# 2839935     2839935      5.0      True   04 5, 2018  A3TN0U64HONOPB
# 2839936     2839936      5.0      True   03 1, 2018   AJDQLM8PT3YWT
# 2839937     2839937      5.0      True  03 17, 2018  A3QK5ZLRE2KHLL
# 2839938     2839938      5.0      True  10 28, 2017  A3VDML80KNR9QQ
# 2839939     2839939      5.0      True  06 11, 2017  A3ONWSRNZFNC3U
#
#                asin         reviewerName  \
# 0        0000032034           Michelle A
# 1        0000032034            Crystal R
# ...

# %%
ratings
# Out:
#                 asin      reviewerID  ratings  unixReviewTime
# 0         0000031895  A2681T699HV6H1      4.0      1384905600
# 1         0000031895  A374PA18DCGS5Y      1.0      1477008000
# 2         0000031895  A14PVW2N5YBWSA      5.0      1476748800
# 3         0000031895  A2KWBC44QI2567      1.0      1476662400
# 4         0000031895  A2WGRWA7BDPF7F      5.0      1474156800
# ...              ...             ...      ...             ...
# 12980831  B01HJHHBHG  A33DFHRKGPDEF7      3.0      1502323200
# 12980832  B01HJHHBHG   AT5N4QPWM1GKL      4.0      1501372800
# 12980833  B01HJHHBHG  A3ONWSRNZFNC3U      5.0      1497139200
# 12980834  B01HJHHBHG  A1OJNTT9ZTT82A      5.0      1496966400
# 12980835  B01HJFUCHO  A2SHB9ITG7EALR      5.0      1526515200
#
# [12980836 rows x 4 columns]
