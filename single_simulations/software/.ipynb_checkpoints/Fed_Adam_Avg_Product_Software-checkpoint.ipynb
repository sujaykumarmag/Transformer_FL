# %%
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import LSTM, Dense, Embedding
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

# %%
df = pd.read_csv("processed_data/final_pre-processed.csv")

# %%
df = df.drop('Unnamed: 0',axis=1)
df["Ratings"] = df["Ratings"].astype(int)

# %%
df
# Out:
#                                              reviewText  Ratings
# 0     Microsoft Office is still the standard all the...        5
# 1     Been using Office for over twenty years.  Stil...        1
# 2     Always liked Office Products.  Expensive for a...        5
# 3     I have been using MS Office professional for d...        5
# 4     This is really a great buy.  It breaks down to...        5
# ...                                                 ...      ...
# 5163  Arrived as described.  I was pleased with purc...        5
# 5164                            Was not what I expected        1
# 5165                                          great buy        4
# 5166  The product itself is quite good, in depth fix...        4
# 5167                                                 ok        4
#
# [5168 rows x 2 columns]

# %%
text_vectorizer = TfidfVectorizer(max_df=.8)
text_vectorizer.fit(df['reviewText'])
def rate(r):
    ary2 = []
    for rating in r:
        tv = [0,0,0,0,0]
        tv[rating-1] = 1
        ary2.append(tv)
    return np.array(ary2)

# %%
X = text_vectorizer.transform(df['reviewText']).toarray()
y = rate(df['Ratings'].values)
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=.2)

# %%
global_model = Sequential()
global_model.add(Dense(128,input_dim=X_train.shape[1]))
global_model.add(Dense(5,activation='softmax'))
# Out:
# Metal device set to: Apple M1

# %%
global_model.compile(loss='categorical_crossentropy',optimizer='rmsprop',metrics=['accuracy'])

# %%
NUM_ROUNDS = 10
NUM_CLIENTS = 10
BATCH_SIZE = 10
EPOCHS_PER_ROUND = 5
LEARNING_RATE = 0.1
BETA_1 = 0.9
BETA_2 = 0.999
EPSILON = 1e-7

# %%
x_train_clients = np.array_split(X_train,NUM_CLIENTS)
y_train_clients = np.array_split(y_train,NUM_CLIENTS)

x_test_clients = np.array_split(X_test,NUM_CLIENTS)
y_test_clients = np.array_split(y_test,NUM_CLIENTS)

# %%
client_models = []
for i in range(NUM_CLIENTS):
    local_model = Sequential()
    local_model.add(Dense(128,input_dim=X_train.shape[1]))
    local_model.add(Dense(5,activation='softmax'))
    local_model.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    local_model.fit(x_train_clients[i],y_train_clients[i],epochs=EPOCHS_PER_ROUND, batch_size=BATCH_SIZE,verbose=0)
    acc = local_model.evaluate(x_test_clients[i],y_test_clients[i])
    print(acc)
    client_models.append(local_model)
# Out:
# 2023-10-10 00:07:47.151601: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 4/4 [==============================] - 1s 181ms/step - loss: 1.0087 - accuracy: 0.6346
# [1.0086694955825806, 0.6346153616905212]
# 4/4 [==============================] - 1s 113ms/step - loss: 1.0580 - accuracy: 0.6442
# [1.0580005645751953, 0.6442307829856873]
# 4/4 [==============================] - 1s 116ms/step - loss: 0.9536 - accuracy: 0.6442
# [0.9536198377609253, 0.6442307829856873]
# 4/4 [==============================] - 1s 118ms/step - loss: 0.9686 - accuracy: 0.6538
# [0.9685941338539124, 0.6538461446762085]
# 4/4 [==============================] - 1s 189ms/step - loss: 1.0028 - accuracy: 0.6408
# [1.0027762651443481, 0.6407766938209534]
# 4/4 [==============================] - 1s 119ms/step - loss: 0.9711 - accuracy: 0.6117
# [0.9711359143257141, 0.6116504669189453]
# 4/4 [==============================] - 1s 121ms/step - loss: 0.9528 - accuracy: 0.6505
# [0.9528199434280396, 0.6504854559898376]
# 4/4 [==============================] - 1s 128ms/step - loss: 1.0235 - accuracy: 0.6117
# [1.0234739780426025, 0.6116504669189453]
# 4/4 [==============================] - 1s 127ms/step - loss: 1.0637 - accuracy: 0.5825
# [1.0637245178222656, 0.582524299621582]
# 4/4 [==============================] - 1s 127ms/step - loss: 0.9051 - accuracy: 0.6117
# [0.9050808548927307, 0.6116504669189453]

# %%
acc = global_model.evaluate(X_test,y_test)
print(acc)
# Out:
# 33/33 [==============================] - 2s 51ms/step - loss: 1.6097 - accuracy: 0.2012
# [1.6097356081008911, 0.20116053521633148]

# %%
# SERVER ADAM OPTIMIZER 
fedadam = tf.optimizers.Adam(learning_rate=LEARNING_RATE,beta_1=BETA_1,beta_2 = BETA_2,epsilon=EPSILON)

# %%
# Performing Federated Averaging
weights = global_model.get_weights()
for i in range(len(weights)):
    for j in range(NUM_CLIENTS):
        client_weights = client_models[j].get_weights()
        weights[i] += client_weights[i]/NUM_CLIENTS

global_model.set_weights(weights)

# %%
acc = global_model.evaluate(X_test,y_test)
print(acc)
# Out:
# 33/33 [==============================] - 1s 43ms/step - loss: 1.4635 - accuracy: 0.6277
# [1.4634984731674194, 0.6276595592498779]

# %%
# Train the Fed AVG model
fed_model = global_model
fed_model.compile(optimizer=fedadam, loss='categorical_crossentropy',metrics=['accuracy'])
fed_model.fit(X_train,y_train,epochs=5,batch_size=20)
# Out:
# Epoch 1/5
# 207/207 [==============================] - 14s 53ms/step - loss: 3.3976 - accuracy: 0.5556
# Epoch 2/5
# 207/207 [==============================] - 10s 48ms/step - loss: 6.4171 - accuracy: 0.7054
# Epoch 3/5
# 207/207 [==============================] - 10s 47ms/step - loss: 5.8558 - accuracy: 0.7799
# Epoch 4/5
# 207/207 [==============================] - 10s 48ms/step - loss: 4.7592 - accuracy: 0.8377
# Epoch 5/5
# 207/207 [==============================] - 10s 49ms/step - loss: 4.1775 - accuracy: 0.8628

# %%
acc = fed_model.evaluate(X_test,y_test)
print(acc)
# Out:
# 33/33 [==============================] - 2s 51ms/step - loss: 23.0158 - accuracy: 0.6325
# [23.015804290771484, 0.6324951648712158]

# %%
# Performing Federated Averaging
def server_update(global_model,client_weights):
    weights = global_model.get_weights()
    for i in range(len(weights)):
        for j in range(NUM_CLIENTS):
            client_weights = client_models[j].get_weights()
            weights[i] += client_weights[i]/NUM_CLIENTS
            global_model.set_weights(weights)

# %%
import numpy as np
import matplotlib.pyplot as plt



# Define the number of clients and epochs
num_clients = 10
num_epochs = 5

accuracy_vs_clients = []
accuracy_vs_epochs = []
# Simulate federated learning rounds
for epoch in range(num_epochs):
    client_weights = []
    
    # Simulate client updates and compute accuracy
    for i in range(num_clients):
        weights = client_models[i].get_weights()
        #weights = client_update(client_models[i], X_train, y_train, epochs=num_epochs, batch_size=batch_size)
        client_models[i].set_weights(weights)
        loss, accuracy = client_models[i].evaluate(X_test, y_test)  # Replace with your test data
        accuracy_vs_clients.append(accuracy)
    
    # Update the global model using Federated Averaging
    server_update(global_model, client_weights)
    
    # Compute accuracy of the global model
    loss, accuracy = global_model.evaluate(X_test, y_test)  # Replace with your test data
    accuracy_vs_epochs.append(accuracy)

# Plot accuracy versus epochs
plt.figure(figsize=(10, 5))
plt.plot(range(1, num_epochs + 1), accuracy_vs_epochs, marker='o')
plt.xlabel('Number of Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy vs. Number of Epochs')
plt.grid(True)
plt.show()

# Plot accuracy versus clients
plt.figure(figsize=(10, 5))
plt.plot(range(1, num_epochs * num_clients + 1), accuracy_vs_clients, marker='o')
plt.xlabel('Number of Clients')
plt.ylabel('Accuracy')
plt.title('Accuracy vs. Number of Clients')
plt.grid(True)
plt.show()
# Out:
# 33/33 [==============================] - 1s 42ms/step - loss: 1.0018 - accuracy: 0.6344
# 33/33 [==============================] - 1s 42ms/step - loss: 0.9900 - accuracy: 0.6335
# 33/33 [==============================] - 1s 42ms/step - loss: 0.9874 - accuracy: 0.6306
# 33/33 [==============================] - 1s 42ms/step - loss: 1.0135 - accuracy: 0.6180
# 33/33 [==============================] - 1s 42ms/step - loss: 1.0046 - accuracy: 0.6306
# 33/33 [==============================] - 1s 42ms/step - loss: 0.9895 - accuracy: 0.6296
# 33/33 [==============================] - 1s 42ms/step - loss: 1.0055 - accuracy: 0.6325
# 33/33 [==============================] - 1s 43ms/step - loss: 0.9899 - accuracy: 0.6286
# 33/33 [==============================] - 1s 43ms/step - loss: 1.0079 - accuracy: 0.6248
# 33/33 [==============================] - 1s 42ms/step - loss: 0.9835 - accuracy: 0.6248
# 33/33 [==============================] - 1s 43ms/step - loss: 24.3232 - accuracy: 0.6335
# 33/33 [==============================] - 1s 42ms/step - loss: 1.0018 - accuracy: 0.6344
# 33/33 [==============================] - 1s 42ms/step - loss: 0.9900 - accuracy: 0.6335
# 33/33 [==============================] - 1s 43ms/step - loss: 0.9874 - accuracy: 0.6306
# 33/33 [==============================] - 1s 42ms/step - loss: 1.0135 - accuracy: 0.6180
# 33/33 [==============================] - 1s 43ms/step - loss: 1.0046 - accuracy: 0.6306
# 33/33 [==============================] - 1s 43ms/step - loss: 0.9895 - accuracy: 0.6296
# 33/33 [==============================] - 1s 43ms/step - loss: 1.0055 - accuracy: 0.6325
# 33/33 [==============================] - 1s 43ms/step - loss: 0.9899 - accuracy: 0.6286
# 33/33 [==============================] - 1s 42ms/step - loss: 1.0079 - accuracy: 0.6248
# 33/33 [==============================] - 1s 43ms/step - loss: 0.9835 - accuracy: 0.6248
# 33/33 [==============================] - 1s 43ms/step - loss: 25.7264 - accuracy: 0.6364
